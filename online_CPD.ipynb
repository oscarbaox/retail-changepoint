# %% [markdown]
# Online CPD is where we detect the beginning of a changepoint or a spike, then use a few subsequent timesteps to determine whether it was a short-lived spike or a longer-duration virality trend.
